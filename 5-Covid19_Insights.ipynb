# %% [markdown]
# # Counting Boats from Space - Part 5

# %%
# %reload_ext autoreload
# %autoreload 2
# %load_ext dotenv
# %dotenv
# %matplotlib inline

# %%
import sys
# !{sys.executable} -m pip install torch
# !{sys.executable} -m pip install torchvision
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.7/site-packages (1.5.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch) (0.18.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from torch) (1.18.4)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.7/site-packages (0.6.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from torchvision) (1.18.4)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from torchvision) (7.1.2)
# Requirement already satisfied: torch==1.5.0 in /opt/conda/lib/python3.7/site-packages (from torchvision) (1.5.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch==1.5.0->torchvision) (0.18.2)

# %%
import src.serve ##### script to scan data/aoi.json in 2019 and 2020
# Out:
# Model version: v0.0.1
# Device: cpu
#
# AOI: Gibraltar, Dover, Bosporus, Dardanelles, Suez, Korinth, Otranto, Messina, Grande Belt, Kiel Canal, Tallin-Helsinki, Panama, Cape of Good Hope, Malacca, Bab-el-Mandeb, Hormuz
# Radius: 5000m
# Cloud coverage (max): 10.0%
# Time window 1: 2019-01-01 / 2019-05-15
# Time window 2: 2020-01-01 / 2020-05-15
# Time period: 5D
# /home/jovyan/michel/sentinel2-xcube-boat-detection/src/serve.py:128: RuntimeWarning: invalid value encountered in double_scalars
#   delta = 100*(np.mean(counts1)-np.mean(counts0))/np.mean(counts0)
# /home/jovyan/michel/sentinel2-xcube-boat-detection/src/serve.py:140: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   plt.ylim(ymin, ymax)
